# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm  # color map
import numpy as np
from scipy.integrate import quad
import random
import math
import warnings
from multiprocessing import Pool
warnings.filterwarnings("ignore")
Mpc = 3.0857e22  # Mega parsec in meters

figuresize = 4
plt.rcParams["figure.figsize"] = (figuresize, figuresize*9.7/12)
plt.rcParams["axes.unicode_minus"] = False
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['text.usetex'] = False

# %% [markdown]
# # Average polarization of multiple clusters
#
# The average Stokes parameters $Q$ & $U$ of multiple rotating galaxy clusters are calculated in the following.
# With the average Stokes paramters can then the degree of polarization $P=\sqrt{Q^2+U^2}$ be calculated.

# %% [markdown]
# ## Parameters definition
# define all parameters of the galaxy cluster:
#
# - `r_c` core radius
# - `r` border radius
# - `n_eo` electron delsity
# - `d` distance to the observer
#
# parameters for the velocity profiles VP1 & VP2:
# - `VP` selects velocity profile 1 or 2
# - `v_c` core velocity for VP1 in units of c
# - `r_0` scale radius for VP2
# - `v_t` scale velocity for VP2 in units of c
#
# Inclination `inclination`$\in (0, 1/2)$ in units of $\pi$
# and rotation along the line of sight `ry`$\in (0, 2\pi)$.
# Rotation along z axis `rz` stays zero

# %%
r_c = 0.2 * Mpc  # core radius
r = 2.8 * Mpc  # maximum radius

n_eo = 2e4  # central electron density
d = 1e6 * Mpc  # distance

# parameters for VP1 & VP2
VP = 2
v_c = 5e-4/3
r_0 = 1.2 * Mpc
v_t = 8e-3/3

# rotation angles
inclination = 0
ry = 0  # rotation angle y-axis - line of sight
rx = np.pi * (1/2 - inclination) # rotation angle x-axis - horizontal axis
rz = 0  # rotation angle z-axis - vertical axis

# %% [markdown]
# `amount` sets the amount of galaxy clusters of wich the average polarization paramters are calculated
#
# define parameters for images. Resolution `e` along x axis. `e²` points are integrated -> calculation time increases $\sim e^2$.
#
# But edit resolution with `short`. `short` defines every how many data points the polarization angle is determined
#
# Viewing angles `c`. $r/d$ corresponds to core radius.

# %%
amount = 100
short = 4
e = 16*short  # Resolution
c = r/d*1.05  # edge limit (angle). r/d is angle for max. radius r

# %% [markdown]
# definde parameters for relative intensity chnage (CMB parameters) then calculate $G_{\nu,\mathrm{pol}}$

# %%
sigma_T = 6.652e-29  # thomson cross section
h = 6.626e-34  # planck constant
k_B = 1.381e-23  # Bolzman constant
T = 2.725  # CMB temperature
nu = 160.2e9  # CMB peak frequency
x = h * nu / k_B / T
G_nu_pol = x**2 * math.exp(x) / 2/(math.exp(x) - 1)**2

beta = 2/3  # for beta model

# %% [markdown]
# ## Function definition
#
# ### Electron density
#  - `beta_model`
#  - `n_e` model from *Vikhlinin*

# %%
def beta_model(x, y, z, n_eo, r_c, beta):
    return n_eo*(1+(x**2+y**2+z**2)/r_c**2)**(-beta * 3/2)


def n_e(x, y, z, n_eo, r_c, beta):
    r = np.sqrt(x**2+y**2+z**2)/r_c
    r_s = 1.7 * Mpc
    alpha = 1
    beta = 0.7
    epsilon = 2.5
    return n_eo*r**(-alpha / 2) / (1+r**2)**(3*beta/2 - alpha/2) / (1+(r*r_c/r_s)**3)**(epsilon/2/3)

# %% [markdown]
# ### Integrands
# for Stokes parameters $Q$ and $U$

# %%
def integrandQ(t, d, theta, phi, n_eo, r_c, beta, rot):
    v = v_p(theta*t, t-d, phi*t, rot)
    return - 1/10 * sigma_T * G_nu_pol * n_e(theta*t, t-d, phi*t, n_eo, r_c, beta) * np.dot(v, v) * np.cos(2 * np.arctan(v[2]/v[0])) * ((theta)**2 + (1)**2 + (phi)**2)**.5


def integrandU(t, d, theta, phi, n_eo, r_c, beta, rot):
    v = v_p(theta*t, t-d, phi*t, rot)
    return - 1/10 * sigma_T * G_nu_pol * n_e(theta*t, t-d, phi*t, n_eo, r_c, beta) * np.dot(v, v) * np.sin(2 * np.arctan(v[2]/v[0])) * ((theta)**2 + (1)**2 + (phi)**2)**.5

# %% [markdown]
# ### Velocity profiles and rotation (inclination)
#
# rotationg velocity vector field with VP1 and VP2. Rotated by an rotation matrix to match inclination and rotation along the line of sight defined above
#
# `v_p` sets $v_2=0$ and selects velocity profile

# %%
def rotMatrix(rx, ry, rz):  # create rotation matrix
    rotx = [[1, 0, 0],
            [0, np.cos(rx), np.sin(rx)],
            [0, -np.sin(rx), np.cos(rx)]]
    roty = [[np.cos(ry), 0, np.sin(ry)],
            [0, 1, 0],
            [-np.sin(ry), 0, np.cos(ry)]]
    rotz = [[np.cos(rz), np.sin(rz), 0],
            [-np.sin(rz), np.cos(rz), 0],
            [0, 0, 1]]
    # firt x-axis, the z-axis, last y-axis. (Keep z-rot = 0)
    rot = np.matmul(roty, np.matmul(rotz, rotx))
    rot[np.abs(rot) < 1e-5] = 0
    return rot.copy()


def rotate(x, y, z, rot):  # rotate koordinates rot^T * vec(r) = vec(r_rot)
    rotXYZ = np.transpose(
        np.matmul(np.transpose(rot), np.array([[x], [y], [z]])))[0]
    return rotXYZ[0], rotXYZ[1], rotXYZ[2]


def VP1(x, y, z, rot):  # Velocity profile 1 - vctor field, rotated
    x, y, z = rotate(x, y, z, rot)
    v_norm = np.transpose(np.matmul(rot, np.array(
        [[-y], [x], [0]])))[0].copy() / np.sqrt(x**2+y**2)  # normalized field
    r = np.sqrt(x**2+y**2)/r_c  # r/r_c
    v = v_c * r  # profile
    return v * v_norm


def VP2(x, y, z, rot):  # Velocity profile 2 - vctor field, rotated
    x, y, z = rotate(x, y, z, rot)
    v_norm = np.transpose(np.matmul(rot, np.array(
        [[-y], [x], [0]])))[0].copy() / np.sqrt(x**2+y**2)  # normalized field
    r = np.sqrt(x**2+y**2)/r_0  # r/r_0
    v = v_t * r / (1+r**2)  # Profile
    return v * v_norm

def v_p(x, y, z, rot):  # get the velocety part perpendicular to the line of sight
    if VP == 1:
        return VP1(x, y, z, rot) * np.array([1, 0, 1])
    return VP2(x, y, z, rot) * np.array([1, 0, 1])

# %% [markdown]
# ### polarization vectors
#
# calculate polarization angle and generate fitting vectors propotional to degree of polarization $P$

# %%
def polarization_vectors(Q, U, P, short):
    # extract a few points from array
    Ushort = U[::short, ::short].copy()
    Qshort = Q[::short, ::short].copy()
    Pshort = P[::short, ::short].copy()
    # calculate pol. angle theta
    angle = np.arctan(Ushort/Qshort)/2
    angle[Qshort < 0] += np.pi/2
    # generate vecors from angle with the length P
    polvec_x = np.cos(angle)*Pshort
    polvec_y = np.sin(angle)*Pshort
    return polvec_x, polvec_y

# %% [markdown]
# ### Integradion function
# Integrate integrands $Q$ & $U$ with `args`

# %%
def integrate_Polarization(args):
    q = np.linspace(0, 0, e)
    Q, U = np.meshgrid(q, q)
    t1, t2, d, Theta, Phi, n_eo, r_c, beta, rot, threats = args[0], args[1],  args[
        2],  args[3],  args[4],  args[5],  args[6],  args[7],  args[8],  args[9]
    Q[Q != 0] = 0
    U[U != 0] = 0
    section_x = args[10]
    section_y = args[11]
    sectionsize = int(e/threats)
    for i in range(sectionsize*section_x, sectionsize*(section_x+1)):
        for j in range(sectionsize*section_y, sectionsize*(section_y+1)):
            theta = Theta[i, j]
            phi = Phi[i, j]
            I = quad(integrandQ, t1[i, j], t2[i, j], args=(
                d, theta, phi, n_eo, r_c, beta, rot))
            Q[i, j] = I[0]
            I = quad(integrandU, t1[i, j], t2[i, j], args=(
                d, theta, phi, n_eo, r_c, beta, rot))
            U[i, j] = I[0]
    return Q.copy(), U.copy()

# %% [markdown]
# ### muliprocessing
#
# run integration in multiple prozesses to speed up calculation

# %%
def integrate_pol_multithreating(t1, t2, d, Theta, Phi, n_eo, r_c, beta, rot, thrts):
    if __name__ == '__main__':
        with Pool() as pool:  # integrate parallel in *#cpu threats* threats
            results = pool.map(integrate_Polarization, [(
                t1, t2, d, Theta, Phi, n_eo, r_c, beta, rot, thrts, i, j) for i in range(thrts) for j in range(thrts)])
    q = np.linspace(0, 0, e)
    Q, U = np.meshgrid(q, q)
    # merge threat results
    for i in range(len(results)):
        q, u = results[i]
        Q += q
        U += u
    return Q, U

# %% [markdown]
# ## Calculation
# ### Limits
# Prepare vairables for calculation
#
# calculate limits t1, t2 for integration along the line of sight. The limits match the galaxy cluster radius along the line of sight.
#
# create the rotation maxtix

# %%
# generate variables for calculation
theta = np.linspace(-c, c, e)
Theta, Phi = np.meshgrid(theta, theta)
# generate empty arrays
t = np.linspace(0, 0, e)
t1, t2 = np.meshgrid(t, t)
Q, U, Q_ges, U_ges, Result = t1.copy(), t1.copy(), t1.copy(), t1.copy(), t1.copy()

# limits for integral. edge of cluster
t1 = (d - np.sqrt(-d**2 * (Phi**2 + Theta**2) + r**2
      * (1 + Phi**2 + Theta**2)))/(1 + Phi**2 + Theta**2)
t2 = (d + np.sqrt(-d**2 * (Phi**2 + Theta**2) + r**2
      * (1 + Phi**2 + Theta**2)))/(1 + Phi**2 + Theta**2)

# %% [markdown]
# ### Integrate
# calculate the Stokes paramters $Q$ & $U$ for all `amount` galaxy clusters with random directions of the rotation axes.

# %%
# %%time
for j in range(amount):
    m = random.random()
    l = random.random()
    print(str(j+1)+"/"+str(amount), ': inclination =' + str(np.round(1/2-m*2, 3)) + 'pi', ', r_y =' + str(np.round(l*2, 3)) + 'pi')
    ry = np.pi*l*2  # rotation angle y-axis - line of sight
    rx = np.pi*m*2  # rotation angle z-axis - vertical axis
    # calc rot
    rot = rotMatrix(rx, ry, 0)
    # calc Stokes
    Q, U = integrate_pol_multithreating(t1, t2, d, Theta, Phi, n_eo, r_c, beta, rot, 16)
    Q_ges = Q_ges + Q
    U_ges = U_ges + U
# Out:
# 1/500 : inclination =-0.83pi , r_y =0.577pi
# 2/500 : inclination =0.39pi , r_y =1.061pi
# 3/500 : inclination =-0.999pi , r_y =1.321pi
# 4/500 : inclination =0.354pi , r_y =1.398pi
# 5/500 : inclination =0.022pi , r_y =1.649pi
# 6/500 : inclination =-0.417pi , r_y =1.453pi
# 7/500 : inclination =-0.787pi , r_y =1.24pi
# 8/500 : inclination =0.34pi , r_y =1.694pi
# 9/500 : inclination =0.37pi , r_y =1.623pi
# 10/500 : inclination =-0.028pi , r_y =1.488pi
# 11/500 : inclination =-1.15pi , r_y =1.492pi
# 12/500 : inclination =-0.402pi , r_y =1.426pi
# 13/500 : inclination =-0.308pi , r_y =0.492pi
# 14/500 : inclination =0.439pi , r_y =0.825pi
# 15/500 : inclination =-0.637pi , r_y =1.178pi
# 16/500 : inclination =-0.314pi , r_y =0.05pi
# 17/500 : inclination =-1.069pi , r_y =0.061pi
# 18/500 : inclination =-0.618pi , r_y =0.964pi
# 19/500 : inclination =0.412pi , r_y =0.951pi
# 20/500 : inclination =0.063pi , r_y =1.708pi
# 21/500 : inclination =0.158pi , r_y =0.783pi
# 22/500 : inclination =-1.213pi , r_y =1.752pi
# 23/500 : inclination =-0.804pi , r_y =1.813pi
# 24/500 : inclination =-0.167pi , r_y =1.111pi
# 25/500 : inclination =0.042pi , r_y =0.012pi
# 26/500 : inclination =-1.136pi , r_y =1.75pi
# 27/500 : inclination =-1.042pi , r_y =0.639pi
# 28/500 : inclination =-0.132pi , r_y =1.735pi
# 29/500 : inclination =0.178pi , r_y =1.075pi
# 30/500 : inclination =-1.424pi , r_y =0.377pi
# 31/500 : inclination =-0.717pi , r_y =0.575pi
# 32/500 : inclination =-0.837pi , r_y =1.052pi
# 33/500 : inclination =-1.192pi , r_y =1.912pi
# 34/500 : inclination =-0.658pi , r_y =0.253pi
# 35/500 : inclination =-0.094pi , r_y =0.883pi
# 36/500 : inclination =0.056pi , r_y =0.337pi
# 37/500 : inclination =-1.127pi , r_y =1.573pi
# 38/500 : inclination =-0.821pi , r_y =0.516pi
# 39/500 : inclination =-0.718pi , r_y =1.487pi
# 40/500 : inclination =-0.642pi , r_y =1.196pi
# 41/500 : inclination =-1.49pi , r_y =0.469pi
# 42/500 : inclination =-0.463pi , r_y =0.37pi
# 43/500 : inclination =0.453pi , r_y =1.347pi
# 44/500 : inclination =-0.853pi , r_y =1.381pi
# 45/500 : inclination =-0.508pi , r_y =1.499pi
# 46/500 : inclination =-0.88pi , r_y =0.154pi
# 47/500 : inclination =-1.079pi , r_y =1.027pi
# 48/500 : inclination =-0.691pi , r_y =0.075pi
# 49/500 : inclination =-0.986pi , r_y =0.877pi
# 50/500 : inclination =0.042pi , r_y =0.302pi
# 51/500 : inclination =0.006pi , r_y =1.824pi
# 52/500 : inclination =-0.393pi , r_y =0.18pi
# 53/500 : inclination =0.054pi , r_y =0.526pi
# 54/500 : inclination =-1.105pi , r_y =1.196pi
# 55/500 : inclination =0.198pi , r_y =0.632pi
# 56/500 : inclination =-0.742pi , r_y =0.792pi
# 57/500 : inclination =-0.548pi , r_y =0.399pi
# 58/500 : inclination =-1.297pi , r_y =1.583pi
# 59/500 : inclination =-0.741pi , r_y =1.816pi
# 60/500 : inclination =-0.62pi , r_y =1.419pi
# 61/500 : inclination =0.449pi , r_y =0.801pi
# 62/500 : inclination =-0.727pi , r_y =1.035pi
# 63/500 : inclination =0.111pi , r_y =1.238pi
# 64/500 : inclination =-1.192pi , r_y =0.395pi
# 65/500 : inclination =0.254pi , r_y =0.915pi
# 66/500 : inclination =-1.35pi , r_y =1.875pi
# 67/500 : inclination =-0.117pi , r_y =1.301pi
# 68/500 : inclination =-0.557pi , r_y =1.242pi
# 69/500 : inclination =-0.816pi , r_y =1.524pi
# 70/500 : inclination =-1.225pi , r_y =1.984pi
# 71/500 : inclination =-1.168pi , r_y =0.336pi
# 72/500 : inclination =-0.228pi , r_y =1.355pi
# 73/500 : inclination =0.424pi , r_y =0.277pi
# 74/500 : inclination =-1.372pi , r_y =1.88pi
# 75/500 : inclination =-0.302pi , r_y =1.867pi
# 76/500 : inclination =-0.208pi , r_y =1.651pi
# 77/500 : inclination =-1.439pi , r_y =0.561pi
# 78/500 : inclination =-0.644pi , r_y =1.765pi
# 79/500 : inclination =-1.384pi , r_y =1.571pi
# 80/500 : inclination =0.259pi , r_y =0.397pi
# 81/500 : inclination =0.399pi , r_y =0.169pi
# 82/500 : inclination =-0.349pi , r_y =0.519pi
# 83/500 : inclination =-0.475pi , r_y =0.113pi
# 84/500 : inclination =-0.001pi , r_y =0.61pi
# 85/500 : inclination =-1.252pi , r_y =1.688pi
# 86/500 : inclination =0.05pi , r_y =0.555pi
# 87/500 : inclination =0.07pi , r_y =0.61pi
# 88/500 : inclination =-0.404pi , r_y =0.934pi
# 89/500 : inclination =-0.382pi , r_y =0.844pi
# 90/500 : inclination =-1.315pi , r_y =1.888pi
# 91/500 : inclination =-0.489pi , r_y =1.634pi
# 92/500 : inclination =-0.679pi , r_y =0.001pi
# 93/500 : inclination =-0.019pi , r_y =0.445pi
# 94/500 : inclination =-0.179pi , r_y =0.72pi
# 95/500 : inclination =-0.937pi , r_y =1.34pi
# 96/500 : inclination =-0.664pi , r_y =0.185pi
# 97/500 : inclination =0.362pi , r_y =0.64pi
# 98/500 : inclination =0.1pi , r_y =1.409pi
# 99/500 : inclination =-0.13pi , r_y =0.263pi
# 100/500 : inclination =0.457pi , r_y =1.76pi
# 101/500 : inclination =-0.938pi , r_y =0.94pi
# 102/500 : inclination =-1.431pi , r_y =1.819pi
# 103/500 : inclination =-0.947pi , r_y =0.305pi
# 104/500 : inclination =-0.94pi , r_y =1.18pi
# 105/500 : inclination =-0.564pi , r_y =1.804pi
# 106/500 : inclination =-0.997pi , r_y =1.218pi
# 107/500 : inclination =0.445pi , r_y =1.239pi
# 108/500 : inclination =-0.89pi , r_y =0.987pi
# 109/500 : inclination =-1.173pi , r_y =0.999pi
# 110/500 : inclination =0.352pi , r_y =1.168pi
# 111/500 : inclination =-0.322pi , r_y =0.938pi
# 112/500 : inclination =-0.169pi , r_y =0.422pi
# 113/500 : inclination =-0.245pi , r_y =0.098pi
# 114/500 : inclination =-0.301pi , r_y =1.083pi
# 115/500 : inclination =-0.832pi , r_y =0.645pi
# 116/500 : inclination =-0.466pi , r_y =1.33pi
# 117/500 : inclination =-0.336pi , r_y =1.784pi
# 118/500 : inclination =-0.515pi , r_y =0.971pi
# 119/500 : inclination =-1.405pi , r_y =1.748pi
# 120/500 : inclination =-0.119pi , r_y =1.391pi
# 121/500 : inclination =-0.914pi , r_y =0.34pi
# 122/500 : inclination =-1.189pi , r_y =0.293pi
# 123/500 : inclination =-1.168pi , r_y =1.561pi
# 124/500 : inclination =-0.117pi , r_y =1.289pi
# 125/500 : inclination =-0.665pi , r_y =1.714pi
# 126/500 : inclination =0.048pi , r_y =0.499pi
# 127/500 : inclination =-0.974pi , r_y =0.555pi
# 128/500 : inclination =-0.26pi , r_y =1.723pi
# 129/500 : inclination =-0.41pi , r_y =1.335pi
# 130/500 : inclination =-0.294pi , r_y =1.059pi
# 131/500 : inclination =-0.076pi , r_y =0.883pi
# 132/500 : inclination =0.098pi , r_y =1.583pi
# 133/500 : inclination =-1.263pi , r_y =0.488pi
# 134/500 : inclination =-0.847pi , r_y =0.804pi
# 135/500 : inclination =-0.826pi , r_y =0.019pi
# 136/500 : inclination =-1.115pi , r_y =0.723pi
# 137/500 : inclination =-0.348pi , r_y =1.283pi
# 138/500 : inclination =-0.865pi , r_y =0.289pi
# 139/500 : inclination =-1.397pi , r_y =0.685pi
# 140/500 : inclination =-1.233pi , r_y =0.588pi
# 141/500 : inclination =-1.148pi , r_y =1.708pi
# 142/500 : inclination =-0.188pi , r_y =1.618pi
# 143/500 : inclination =-0.728pi , r_y =0.853pi
# 144/500 : inclination =-1.303pi , r_y =1.615pi
# 145/500 : inclination =-0.541pi , r_y =1.932pi
# 146/500 : inclination =0.045pi , r_y =1.456pi
# 147/500 : inclination =-0.607pi , r_y =1.822pi
# 148/500 : inclination =0.351pi , r_y =1.05pi
# 149/500 : inclination =-0.377pi , r_y =1.067pi
# 150/500 : inclination =-1.212pi , r_y =1.927pi
# 151/500 : inclination =-1.157pi , r_y =0.024pi
# 152/500 : inclination =-1.199pi , r_y =0.867pi
# 153/500 : inclination =0.064pi , r_y =0.457pi
# 154/500 : inclination =0.187pi , r_y =1.87pi
# 155/500 : inclination =0.291pi , r_y =1.896pi
# 156/500 : inclination =-0.469pi , r_y =0.023pi
# 157/500 : inclination =0.175pi , r_y =0.569pi
# 158/500 : inclination =-0.017pi , r_y =1.42pi
# 159/500 : inclination =-0.166pi , r_y =0.913pi
# 160/500 : inclination =-0.709pi , r_y =1.035pi
# 161/500 : inclination =0.327pi , r_y =1.907pi
# 162/500 : inclination =-1.244pi , r_y =1.161pi
# 163/500 : inclination =-0.961pi , r_y =0.281pi
# 164/500 : inclination =-1.186pi , r_y =0.271pi
# 165/500 : inclination =0.174pi , r_y =1.848pi
# 166/500 : inclination =-0.798pi , r_y =1.014pi
# 167/500 : inclination =0.442pi , r_y =1.08pi
# 168/500 : inclination =-1.487pi , r_y =0.989pi
# 169/500 : inclination =-1.08pi , r_y =1.903pi
# 170/500 : inclination =-1.327pi , r_y =0.713pi
# 171/500 : inclination =-0.058pi , r_y =0.079pi
# 172/500 : inclination =-0.969pi , r_y =0.207pi
# 173/500 : inclination =-0.562pi , r_y =0.668pi
# 174/500 : inclination =-1.408pi , r_y =0.682pi
# 175/500 : inclination =0.121pi , r_y =0.805pi
# 176/500 : inclination =-0.016pi , r_y =1.723pi
# 177/500 : inclination =0.275pi , r_y =1.573pi
# 178/500 : inclination =-0.674pi , r_y =1.293pi
# 179/500 : inclination =0.139pi , r_y =0.175pi
# 180/500 : inclination =0.474pi , r_y =1.958pi
# 181/500 : inclination =-1.244pi , r_y =0.154pi
# 182/500 : inclination =0.242pi , r_y =0.881pi
# 183/500 : inclination =0.034pi , r_y =1.611pi
# 184/500 : inclination =0.259pi , r_y =0.855pi
# 185/500 : inclination =0.407pi , r_y =1.401pi
# 186/500 : inclination =-1.374pi , r_y =0.085pi
# 187/500 : inclination =-1.375pi , r_y =1.643pi
# 188/500 : inclination =-0.943pi , r_y =0.23pi
# 189/500 : inclination =0.331pi , r_y =1.883pi
# 190/500 : inclination =0.424pi , r_y =0.935pi
# 191/500 : inclination =-1.217pi , r_y =1.475pi
# 192/500 : inclination =-1.423pi , r_y =1.989pi
# 193/500 : inclination =-0.663pi , r_y =0.923pi
# 194/500 : inclination =0.087pi , r_y =0.647pi
# 195/500 : inclination =-0.378pi , r_y =1.716pi
# 196/500 : inclination =-1.154pi , r_y =1.112pi
# 197/500 : inclination =-1.377pi , r_y =1.258pi
# 198/500 : inclination =-0.339pi , r_y =0.968pi
# 199/500 : inclination =-0.713pi , r_y =0.757pi
# 200/500 : inclination =-1.121pi , r_y =1.185pi
# 201/500 : inclination =-0.477pi , r_y =1.325pi
# 202/500 : inclination =-1.222pi , r_y =0.732pi
# 203/500 : inclination =-0.673pi , r_y =1.087pi
# 204/500 : inclination =-0.357pi , r_y =1.741pi
# 205/500 : inclination =-0.041pi , r_y =1.456pi
# 206/500 : inclination =-0.158pi , r_y =1.667pi
# 207/500 : inclination =-1.235pi , r_y =1.502pi
# 208/500 : inclination =-1.098pi , r_y =0.949pi
# 209/500 : inclination =-1.145pi , r_y =1.992pi
# 210/500 : inclination =-0.309pi , r_y =1.838pi
# 211/500 : inclination =-1.064pi , r_y =1.503pi
# 212/500 : inclination =-1.325pi , r_y =0.104pi
# 213/500 : inclination =-0.721pi , r_y =1.895pi
# 214/500 : inclination =-0.76pi , r_y =0.007pi
# 215/500 : inclination =0.38pi , r_y =0.271pi
# 216/500 : inclination =0.298pi , r_y =1.013pi
# 217/500 : inclination =0.206pi , r_y =0.435pi
# 218/500 : inclination =-0.394pi , r_y =1.113pi
# 219/500 : inclination =-0.063pi , r_y =0.74pi
# 220/500 : inclination =-1.116pi , r_y =0.23pi
# 221/500 : inclination =-0.657pi , r_y =1.907pi
# 222/500 : inclination =-1.161pi , r_y =1.411pi
# 223/500 : inclination =-0.883pi , r_y =1.084pi
# 224/500 : inclination =0.025pi , r_y =0.203pi
# 225/500 : inclination =-0.906pi , r_y =0.461pi
# 226/500 : inclination =-0.287pi , r_y =0.239pi
# 227/500 : inclination =-0.455pi , r_y =0.217pi
# 228/500 : inclination =0.431pi , r_y =1.453pi
# 229/500 : inclination =0.059pi , r_y =0.624pi
# 230/500 : inclination =-0.015pi , r_y =0.029pi
# 231/500 : inclination =-0.841pi , r_y =1.268pi
# 232/500 : inclination =0.072pi , r_y =0.602pi
# 233/500 : inclination =-0.176pi , r_y =0.698pi
# 234/500 : inclination =-0.548pi , r_y =0.523pi
# 235/500 : inclination =0.383pi , r_y =0.714pi
# 236/500 : inclination =0.304pi , r_y =1.145pi
# 237/500 : inclination =0.016pi , r_y =0.788pi
# 238/500 : inclination =-0.51pi , r_y =0.189pi
# 239/500 : inclination =-0.884pi , r_y =0.221pi
# 240/500 : inclination =-0.157pi , r_y =0.441pi
# 241/500 : inclination =-0.922pi , r_y =0.722pi
# 242/500 : inclination =-0.427pi , r_y =0.736pi
# 243/500 : inclination =-0.478pi , r_y =0.697pi
# 244/500 : inclination =-0.871pi , r_y =1.796pi
# 245/500 : inclination =-0.721pi , r_y =0.582pi
# 246/500 : inclination =0.478pi , r_y =1.828pi
# 247/500 : inclination =-0.594pi , r_y =1.775pi
# 248/500 : inclination =0.126pi , r_y =1.199pi
# 249/500 : inclination =-1.186pi , r_y =1.822pi
# 250/500 : inclination =-0.243pi , r_y =0.749pi
# 251/500 : inclination =-0.18pi , r_y =0.793pi
# 252/500 : inclination =-1.074pi , r_y =0.666pi
# 253/500 : inclination =-1.352pi , r_y =0.039pi
# 254/500 : inclination =-0.935pi , r_y =0.161pi
# 255/500 : inclination =0.224pi , r_y =0.419pi
# 256/500 : inclination =-0.532pi , r_y =0.596pi
# 257/500 : inclination =-0.872pi , r_y =1.242pi
# 258/500 : inclination =-0.815pi , r_y =1.522pi
# 259/500 : inclination =-1.09pi , r_y =0.035pi
# 260/500 : inclination =-0.364pi , r_y =1.359pi
# 261/500 : inclination =0.229pi , r_y =1.226pi
# 262/500 : inclination =0.175pi , r_y =1.989pi
# 263/500 : inclination =0.25pi , r_y =0.311pi
# 264/500 : inclination =0.325pi , r_y =0.123pi
# 265/500 : inclination =-0.49pi , r_y =0.6pi
# 266/500 : inclination =0.208pi , r_y =0.705pi
# 267/500 : inclination =-0.516pi , r_y =1.685pi
# 268/500 : inclination =-0.231pi , r_y =1.518pi
# 269/500 : inclination =-0.196pi , r_y =1.312pi
# 270/500 : inclination =-0.493pi , r_y =0.146pi
# 271/500 : inclination =-0.66pi , r_y =1.869pi
# 272/500 : inclination =-0.749pi , r_y =0.178pi
# 273/500 : inclination =-0.747pi , r_y =1.414pi
# 274/500 : inclination =-0.881pi , r_y =1.144pi
# 275/500 : inclination =-0.207pi , r_y =1.56pi
# 276/500 : inclination =-1.34pi , r_y =1.021pi
# 277/500 : inclination =0.32pi , r_y =0.177pi
# 278/500 : inclination =-0.426pi , r_y =1.191pi
# 279/500 : inclination =-1.178pi , r_y =0.488pi
# 280/500 : inclination =-0.413pi , r_y =1.632pi
# 281/500 : inclination =0.396pi , r_y =0.761pi
# 282/500 : inclination =-0.284pi , r_y =0.21pi
# 283/500 : inclination =-0.955pi , r_y =0.969pi
# 284/500 : inclination =-0.484pi , r_y =0.276pi
# 285/500 : inclination =-0.042pi , r_y =0.495pi
# 286/500 : inclination =0.332pi , r_y =0.411pi
# 287/500 : inclination =-0.88pi , r_y =0.132pi
# 288/500 : inclination =-1.008pi , r_y =1.376pi
# 289/500 : inclination =-1.125pi , r_y =0.152pi
# 290/500 : inclination =-0.206pi , r_y =0.838pi
# 291/500 : inclination =0.258pi , r_y =1.279pi
# 292/500 : inclination =-0.316pi , r_y =1.654pi
# 293/500 : inclination =-0.433pi , r_y =0.513pi
# 294/500 : inclination =-0.453pi , r_y =1.077pi
# 295/500 : inclination =-0.181pi , r_y =1.081pi
# 296/500 : inclination =-0.526pi , r_y =1.752pi
# 297/500 : inclination =0.225pi , r_y =0.208pi
# 298/500 : inclination =-0.794pi , r_y =1.779pi
# 299/500 : inclination =0.039pi , r_y =0.553pi
# 300/500 : inclination =-1.228pi , r_y =0.356pi
# 301/500 : inclination =-0.415pi , r_y =0.447pi
# 302/500 : inclination =-1.065pi , r_y =1.904pi
# 303/500 : inclination =-0.323pi , r_y =0.2pi
# 304/500 : inclination =0.327pi , r_y =0.765pi
# 305/500 : inclination =-1.289pi , r_y =1.155pi
# 306/500 : inclination =-0.526pi , r_y =1.342pi
# 307/500 : inclination =-0.978pi , r_y =1.422pi
# 308/500 : inclination =-0.251pi , r_y =1.411pi
# 309/500 : inclination =-0.107pi , r_y =1.645pi
# 310/500 : inclination =-0.16pi , r_y =0.379pi
# 311/500 : inclination =-0.189pi , r_y =0.274pi
# 312/500 : inclination =-1.459pi , r_y =1.389pi
# 313/500 : inclination =-0.243pi , r_y =0.758pi
# 314/500 : inclination =-0.441pi , r_y =0.674pi
# 315/500 : inclination =-0.703pi , r_y =0.488pi
# 316/500 : inclination =-1.151pi , r_y =1.033pi
# 317/500 : inclination =0.234pi , r_y =1.919pi
# 318/500 : inclination =-0.16pi , r_y =0.158pi
# 319/500 : inclination =-0.216pi , r_y =0.961pi
# 320/500 : inclination =0.431pi , r_y =1.745pi
# 321/500 : inclination =-1.081pi , r_y =1.134pi
# 322/500 : inclination =-0.993pi , r_y =0.911pi
# 323/500 : inclination =0.113pi , r_y =1.799pi
# 324/500 : inclination =0.189pi , r_y =1.792pi
# 325/500 : inclination =-0.063pi , r_y =0.085pi
# 326/500 : inclination =-1.365pi , r_y =1.939pi
# 327/500 : inclination =0.364pi , r_y =0.091pi
# 328/500 : inclination =-0.309pi , r_y =0.358pi
# 329/500 : inclination =0.237pi , r_y =0.485pi
# 330/500 : inclination =0.144pi , r_y =1.161pi
# 331/500 : inclination =0.278pi , r_y =1.256pi
# 332/500 : inclination =0.408pi , r_y =1.96pi
# 333/500 : inclination =-0.948pi , r_y =0.239pi
# 334/500 : inclination =-0.526pi , r_y =0.401pi
# 335/500 : inclination =0.322pi , r_y =1.506pi
# 336/500 : inclination =0.288pi , r_y =0.445pi
# 337/500 : inclination =0.259pi , r_y =1.219pi
# 338/500 : inclination =0.116pi , r_y =0.107pi
# 339/500 : inclination =-1.15pi , r_y =1.362pi
# 340/500 : inclination =0.318pi , r_y =0.851pi
# 341/500 : inclination =-1.42pi , r_y =1.174pi
# 342/500 : inclination =-0.947pi , r_y =1.899pi
# 343/500 : inclination =-0.187pi , r_y =1.975pi
# 344/500 : inclination =-0.482pi , r_y =1.464pi
# 345/500 : inclination =0.463pi , r_y =0.419pi
# 346/500 : inclination =-0.872pi , r_y =1.551pi
# 347/500 : inclination =-0.699pi , r_y =0.722pi
# 348/500 : inclination =0.026pi , r_y =1.005pi
# 349/500 : inclination =0.104pi , r_y =0.336pi
# 350/500 : inclination =-0.846pi , r_y =0.781pi
# 351/500 : inclination =-0.174pi , r_y =1.197pi
# 352/500 : inclination =-0.026pi , r_y =1.688pi
# 353/500 : inclination =-0.645pi , r_y =0.255pi
# 354/500 : inclination =-1.218pi , r_y =0.206pi
# 355/500 : inclination =0.138pi , r_y =1.524pi
# 356/500 : inclination =-1.283pi , r_y =1.147pi
# 357/500 : inclination =0.34pi , r_y =0.035pi
# 358/500 : inclination =-0.349pi , r_y =1.431pi
# 359/500 : inclination =-1.2pi , r_y =0.231pi
# 360/500 : inclination =-1.462pi , r_y =1.584pi
# 361/500 : inclination =-0.928pi , r_y =0.657pi
# 362/500 : inclination =-1.122pi , r_y =1.842pi
# 363/500 : inclination =-0.265pi , r_y =0.818pi
# 364/500 : inclination =0.192pi , r_y =0.365pi
# 365/500 : inclination =-0.873pi , r_y =1.14pi
# 366/500 : inclination =-1.086pi , r_y =0.755pi
# 367/500 : inclination =-1.127pi , r_y =0.327pi
# 368/500 : inclination =-0.047pi , r_y =1.06pi
# 369/500 : inclination =0.495pi , r_y =1.802pi
# 370/500 : inclination =-0.051pi , r_y =0.678pi
# 371/500 : inclination =-1.26pi , r_y =1.411pi
# 372/500 : inclination =0.2pi , r_y =0.849pi
# 373/500 : inclination =-0.77pi , r_y =0.311pi
# 374/500 : inclination =0.084pi , r_y =1.029pi
# 375/500 : inclination =-0.368pi , r_y =0.508pi
# 376/500 : inclination =-0.88pi , r_y =0.355pi
# 377/500 : inclination =0.421pi , r_y =1.609pi
# 378/500 : inclination =-0.596pi , r_y =1.689pi
# 379/500 : inclination =-0.901pi , r_y =1.624pi
# 380/500 : inclination =-0.259pi , r_y =1.692pi
# 381/500 : inclination =0.026pi , r_y =1.782pi
# 382/500 : inclination =-1.303pi , r_y =1.106pi
# 383/500 : inclination =0.052pi , r_y =0.952pi
# 384/500 : inclination =0.434pi , r_y =0.346pi
# 385/500 : inclination =0.255pi , r_y =1.002pi
# 386/500 : inclination =0.278pi , r_y =0.047pi
# 387/500 : inclination =-0.99pi , r_y =1.189pi
# 388/500 : inclination =-0.967pi , r_y =1.284pi
# 389/500 : inclination =-0.926pi , r_y =1.766pi
# 390/500 : inclination =-0.687pi , r_y =0.873pi
# 391/500 : inclination =-0.879pi , r_y =0.678pi
# 392/500 : inclination =0.441pi , r_y =0.157pi
# 393/500 : inclination =0.471pi , r_y =1.349pi
# 394/500 : inclination =-1.404pi , r_y =0.114pi
# 395/500 : inclination =-0.332pi , r_y =0.375pi
# 396/500 : inclination =-0.174pi , r_y =0.77pi
# 397/500 : inclination =-0.215pi , r_y =1.318pi
# 398/500 : inclination =-1.134pi , r_y =0.828pi
# 399/500 : inclination =0.122pi , r_y =0.654pi
# 400/500 : inclination =-0.679pi , r_y =1.751pi
# 401/500 : inclination =-1.46pi , r_y =0.87pi
# 402/500 : inclination =0.01pi , r_y =1.11pi
# 403/500 : inclination =-0.808pi , r_y =1.724pi
# 404/500 : inclination =0.053pi , r_y =0.475pi
# 405/500 : inclination =0.024pi , r_y =1.585pi
# 406/500 : inclination =-1.355pi , r_y =1.204pi
# 407/500 : inclination =0.299pi , r_y =0.062pi
# 408/500 : inclination =-0.86pi , r_y =0.137pi
# 409/500 : inclination =0.064pi , r_y =1.747pi
# 410/500 : inclination =0.463pi , r_y =1.196pi
# 411/500 : inclination =-1.113pi , r_y =1.278pi
# 412/500 : inclination =-0.694pi , r_y =1.357pi
# 413/500 : inclination =0.301pi , r_y =0.21pi
# 414/500 : inclination =-1.393pi , r_y =0.835pi
# 415/500 : inclination =-1.153pi , r_y =1.36pi
# 416/500 : inclination =0.499pi , r_y =1.351pi
# 417/500 : inclination =0.236pi , r_y =0.467pi
# 418/500 : inclination =-1.34pi , r_y =1.774pi
# 419/500 : inclination =-0.934pi , r_y =0.338pi
# 420/500 : inclination =-0.641pi , r_y =0.204pi
# 421/500 : inclination =-1.046pi , r_y =1.885pi
# 422/500 : inclination =-1.148pi , r_y =1.903pi
# 423/500 : inclination =-0.443pi , r_y =0.426pi
# 424/500 : inclination =-0.171pi , r_y =1.527pi
# 425/500 : inclination =-0.836pi , r_y =1.466pi
# 426/500 : inclination =-0.071pi , r_y =1.791pi
# 427/500 : inclination =-0.598pi , r_y =0.833pi
# 428/500 : inclination =-1.211pi , r_y =0.912pi
# 429/500 : inclination =-0.997pi , r_y =0.691pi
# 430/500 : inclination =-0.41pi , r_y =0.968pi
# 431/500 : inclination =0.385pi , r_y =0.556pi
# 432/500 : inclination =-0.656pi , r_y =1.427pi
# 433/500 : inclination =0.417pi , r_y =1.7pi
# 434/500 : inclination =0.224pi , r_y =0.9pi
# 435/500 : inclination =-0.564pi , r_y =0.942pi
# 436/500 : inclination =-0.241pi , r_y =0.386pi
# 437/500 : inclination =0.273pi , r_y =1.902pi
# 438/500 : inclination =0.466pi , r_y =0.802pi
# 439/500 : inclination =-1.397pi , r_y =0.567pi
# 440/500 : inclination =0.029pi , r_y =0.461pi
# 441/500 : inclination =-1.215pi , r_y =0.76pi
# 442/500 : inclination =-0.055pi , r_y =1.084pi
# 443/500 : inclination =0.284pi , r_y =0.846pi
# 444/500 : inclination =0.196pi , r_y =1.434pi
# 445/500 : inclination =-1.497pi , r_y =1.978pi
# 446/500 : inclination =-1.138pi , r_y =1.164pi
# 447/500 : inclination =0.334pi , r_y =1.958pi
# 448/500 : inclination =-0.199pi , r_y =0.685pi
# 449/500 : inclination =-0.078pi , r_y =0.39pi
# 450/500 : inclination =0.14pi , r_y =1.442pi
# 451/500 : inclination =0.098pi , r_y =0.25pi
# 452/500 : inclination =-0.708pi , r_y =1.265pi
# 453/500 : inclination =-0.21pi , r_y =1.917pi
# 454/500 : inclination =0.292pi , r_y =0.729pi
# 455/500 : inclination =-0.682pi , r_y =1.093pi
# 456/500 : inclination =-0.596pi , r_y =0.992pi
# 457/500 : inclination =-1.432pi , r_y =0.838pi
# 458/500 : inclination =-0.224pi , r_y =0.787pi
# 459/500 : inclination =-0.177pi , r_y =0.226pi
# 460/500 : inclination =0.094pi , r_y =1.906pi
# 461/500 : inclination =-0.104pi , r_y =1.268pi
# 462/500 : inclination =0.347pi , r_y =1.724pi
# 463/500 : inclination =-0.563pi , r_y =1.615pi
# 464/500 : inclination =-0.857pi , r_y =0.833pi
# 465/500 : inclination =-0.422pi , r_y =1.03pi
# 466/500 : inclination =-0.327pi , r_y =1.783pi
# 467/500 : inclination =0.169pi , r_y =1.511pi
# 468/500 : inclination =-0.633pi , r_y =1.76pi
# 469/500 : inclination =-0.717pi , r_y =0.731pi
# 470/500 : inclination =-1.194pi , r_y =0.932pi
# 471/500 : inclination =-0.689pi , r_y =1.431pi
# 472/500 : inclination =-1.28pi , r_y =1.73pi
# 473/500 : inclination =-0.181pi , r_y =1.182pi
# 474/500 : inclination =-1.165pi , r_y =0.665pi
# 475/500 : inclination =-0.441pi , r_y =0.957pi
# 476/500 : inclination =-0.235pi , r_y =1.79pi
# 477/500 : inclination =-1.297pi , r_y =0.117pi
# 478/500 : inclination =-1.202pi , r_y =1.109pi
# 479/500 : inclination =-0.334pi , r_y =1.525pi
# 480/500 : inclination =-0.91pi , r_y =1.857pi
# 481/500 : inclination =-0.274pi , r_y =0.583pi
# 482/500 : inclination =0.168pi , r_y =0.546pi
# 483/500 : inclination =-0.769pi , r_y =1.823pi
# 484/500 : inclination =-0.839pi , r_y =0.874pi
# 485/500 : inclination =-1.229pi , r_y =1.387pi
# 486/500 : inclination =-0.322pi , r_y =1.19pi
# 487/500 : inclination =-0.306pi , r_y =1.997pi
# 488/500 : inclination =-1.151pi , r_y =0.054pi
# 489/500 : inclination =0.155pi , r_y =1.186pi
# 490/500 : inclination =-1.111pi , r_y =1.556pi
# 491/500 : inclination =-0.314pi , r_y =0.488pi
# 492/500 : inclination =-1.45pi , r_y =1.668pi
# 493/500 : inclination =-0.54pi , r_y =1.104pi
# 494/500 : inclination =0.415pi , r_y =1.894pi
# 495/500 : inclination =0.48pi , r_y =1.032pi
# 496/500 : inclination =-0.088pi , r_y =0.313pi
# 497/500 : inclination =-0.617pi , r_y =1.492pi
# 498/500 : inclination =-0.84pi , r_y =0.542pi
# 499/500 : inclination =-1.074pi , r_y =1.627pi
# 500/500 : inclination =-0.304pi , r_y =0.327pi
# CPU times: user 1min 45s, sys: 38.6 s, total: 2min 24s
# Wall time: 1h 24min 26s

# %% [markdown]
# Calculate the average `Qavrg` and `Uavrg` of the $Q$'s & $U$'s of all galaxy clusters. Determin the average degree of polarization `Pavrg` with `Qavrg` and `Uavrg`
#
# calculate polarization plane vectors
#
# determin max(|`Qavrg`| and |`Uavrg`|) for relative plots

# %%
Qavrg = Q_ges/amount
Uavrg = U_ges/amount
Pavrg = np.sqrt(Qavrg**2 + Uavrg**2)

polvec_x, polvec_y = polarization_vectors(Qavrg, Uavrg, Pavrg, short)

Qavrg[np.isnan(Qavrg)] = 0
Uavrg[np.isnan(Uavrg)] = 0
Qavrg_max = np.abs(np.max(Qavrg))
Qavrg_min = np.abs(np.min(Qavrg))
Uavrg_max = np.abs(np.max(Uavrg))
Uavrg_min = np.abs(np.min(Uavrg))
max = np.max(np.array([Qavrg_min, Qavrg_max, Uavrg_min, Uavrg_max]))
# set 0 to nan to plot white
Qavrg[Qavrg == 0] = np.NaN
Uavrg[Uavrg == 0] = np.NaN
Pavrg[Pavrg == 0] = np.NaN

# %% [markdown]
# save results for possible merge

# %%
savecount = np.load('saves/count.npz')['savecount']
savecount += 1
print(savecount)
np.savez_compressed('saves/count.npz', savecount=savecount)
np.savez_compressed('saves/multisavefile_nr%i.npz' % savecount, Q=Qavrg, U=Uavrg,
                    P=Pavrg, polvec_x=polvec_x, polvec_y=polvec_y, amount=amount)
# Out:
# 6

# %% [markdown]
# ## Plots
# ### svg's
# Generate plot for VP1 and VP2. Also a normalized Prot to compare VP1 and VP2 along the x-axis.
#
# Save the plots as svg with latex text.

# %%
# edit colorgradient of diagram
colors = cm.get_cmap('coolwarm', 200)
colorcrop = colors(np.linspace(.5, 1, 256))
newcmp = matplotlib.colors.ListedColormap(colorcrop)

plt.contourf(Theta*d/r_c, Phi*d/r_c, Pavrg, 100, cmap=newcmp)
plt.colorbar().set_label("\$P\$", labelpad=-5, y=1.08, rotation=0)
plt.quiver(Theta[::short, ::short]*d/r_c, Phi[::short, ::short] * d/r_c, polvec_x, polvec_y, pivot='mid', headlength=0, headwidth=1)
plt.xlabel("x / \$r_c\$")
plt.ylabel("z / \$r_c\$")
plt.savefig("figs/P-multi"+str(amount)+"Nr"+str(savecount)+".svg")
plt.close()

Pavrg[np.isnan(Pavrg)] = 0
plt.plot(Theta[int(e/2)]*d/r_c, Pavrg[int(e/2)], c='black')
plt.xlabel("x / \$r_c\$")
plt.ylabel("\$P\$")
plt.savefig("figs/P2d-multi"+str(amount)+"Nr"+str(savecount)+".svg")
plt.close()
Pavrg[Pavrg == 0] = np.NaN

plt.contourf(Theta*d/r_c, Phi*d/r_c, Qavrg, 100,
             cmap='coolwarm', vmin=-max, vmax=max)
plt.xlabel("x / \$r_c\$")
plt.ylabel("z / \$r_c\$")
plt.colorbar().set_label("\$Q/ I_0\$", labelpad=-5, y=1.08, rotation=0)
plt.savefig("figs/Q-multi"+str(amount)+"Nr"+str(savecount)+".svg")
plt.close()

plt.contourf(Theta*d/r_c, Phi*d/r_c, Uavrg, 100,
             cmap='coolwarm', vmin=-max, vmax=max)
plt.xlabel("x / \$r_c\$")
plt.ylabel("z / \$r_c\$")
plt.colorbar().set_label("\$U / I_0\$", labelpad=-5, y=1.08, rotation=0)
plt.savefig("figs/U-multi"+str(amount)+"Nr"+str(savecount)+".svg")
plt.close()

# %% [markdown]
# ### Show
#
# generate plots again but show them this time (optional export as PNG)

# %%
figuresize = 8
plt.rcParams["figure.figsize"] = (figuresize, figuresize*9.7/12)

plt.contourf(Theta*d/r_c, Phi*d/r_c, Pavrg, 100, cmap=newcmp)
# degree of polarization
plt.colorbar().set_label("$P$", labelpad=-5, y=1.08, rotation=0)
# polarization angles
plt.quiver(Theta[::short, ::short]*d/r_c, Phi[::short, ::short]* d/r_c, polvec_x, polvec_y, pivot='mid', headlength=0, headwidth=1)
plt.xlabel("x / $r_c$")
plt.ylabel("z / $r_c$")
plt.title("P")
plt.show()

# cut
Pavrg[np.isnan(Pavrg)] = 0
plt.plot(Theta[int(e/2)]*d/r_c, Pavrg[int(e/2)], c='black')
Pavrg[Pavrg == 0] = np.NaN
plt.xlabel("x / $r_c$")
plt.ylabel("$P$")
plt.title("P")
plt.show()

plt.contourf(Theta*d/r_c, Phi*d/r_c, Qavrg, 100,
             cmap='coolwarm', vmin=-max, vmax=max)
plt.xlabel("x / $r_c$")
plt.ylabel("z / $r_c$")
plt.colorbar().set_label("$Q/ I_0$", labelpad=-5, y=1.08, rotation=0)
plt.title("Q")
plt.show()

plt.contourf(Theta*d/r_c, Phi*d/r_c, Uavrg, 100,
             cmap='coolwarm', vmin=-max, vmax=max)
plt.xlabel("x / $r_c$")
plt.ylabel("z / $r_c$")
plt.colorbar().set_label("$U / I_0$", labelpad=-5, y=1.08, rotation=0)
plt.title("U")
plt.show()
